# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SimpleRNN
from keras.datasets import imdb
from keras.metrics import Precision, Recall
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=5000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
max_features = 5000
maxlen = 300
batch_size = 64

# %%
print(len(x_train))
print(len(x_test))
# Out:
# 25000
# 25000

# %%
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
model = Sequential()
model.add(Embedding(max_features, 128, input_length=maxlen))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 300, 128)          640000
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 771713 (2.94 MB)
# Trainable params: 771713 (2.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', Precision(), Recall()])

# %%
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 391/391 [==============================] - 550s 1s/step - loss: 0.4771 - accuracy: 0.7705 - precision: 0.7838 - recall: 0.7470 - val_loss: 0.3630 - val_accuracy: 0.8514 - val_precision: 0.8660 - val_recall: 0.8315
# Epoch 2/5
# 391/391 [==============================] - 544s 1s/step - loss: 0.2932 - accuracy: 0.8817 - precision: 0.8773 - recall: 0.8874 - val_loss: 0.3396 - val_accuracy: 0.8518 - val_precision: 0.7997 - val_recall: 0.9388
# Epoch 3/5
# 391/391 [==============================] - 533s 1s/step - loss: 0.2337 - accuracy: 0.9091 - precision: 0.9061 - recall: 0.9127 - val_loss: 0.3132 - val_accuracy: 0.8744 - val_precision: 0.8571 - val_recall: 0.8987
# Epoch 4/5
# 391/391 [==============================] - 543s 1s/step - loss: 0.2012 - accuracy: 0.9230 - precision: 0.9207 - recall: 0.9257 - val_loss: 0.3380 - val_accuracy: 0.8658 - val_precision: 0.8572 - val_recall: 0.8777
# Epoch 5/5
# 391/391 [==============================] - 543s 1s/step - loss: 0.1826 - accuracy: 0.9294 - precision: 0.9285 - recall: 0.9306 - val_loss: 0.4492 - val_accuracy: 0.8372 - val_precision: 0.9119 - val_recall: 0.7466

# %%
model.evaluate(x_test, y_test)
# Out:
# 782/782 [==============================] - 102s 131ms/step - loss: 0.4492 - accuracy: 0.8372 - precision: 0.9119 - recall: 0.7466
# [0.44917765259742737,
#  0.8371999859809875,
#  0.9118624329566956,
#  0.7465599775314331]

# %%
model = Sequential()
model.add(Embedding(max_features, 128, input_length=maxlen))
model.add(SimpleRNN(128))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 300, 128)          640000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 673025 (2.57 MB)
# Trainable params: 673025 (2.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', Precision(), Recall()])
history2 = model.fit(x_train, y_train, batch_size=batch_size, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 391/391 [==============================] - 95s 240ms/step - loss: 0.6572 - accuracy: 0.6148 - precision_1: 0.6160 - recall_1: 0.6094 - val_loss: 0.6904 - val_accuracy: 0.5169 - val_precision_1: 0.6450 - val_recall_1: 0.0753
# Epoch 2/5
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6101 - accuracy: 0.6607 - precision_1: 0.6613 - recall_1: 0.6588 - val_loss: 0.5732 - val_accuracy: 0.6914 - val_precision_1: 0.7455 - val_recall_1: 0.5810
# Epoch 3/5
# 391/391 [==============================] - 92s 237ms/step - loss: 0.5129 - accuracy: 0.7504 - precision_1: 0.7619 - recall_1: 0.7284 - val_loss: 0.5667 - val_accuracy: 0.7234 - val_precision_1: 0.6659 - val_recall_1: 0.8966
# Epoch 4/5
# 391/391 [==============================] - 91s 234ms/step - loss: 0.4975 - accuracy: 0.7596 - precision_1: 0.7605 - recall_1: 0.7578 - val_loss: 0.6753 - val_accuracy: 0.5476 - val_precision_1: 0.5274 - val_recall_1: 0.9182
# Epoch 5/5
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5539 - accuracy: 0.7021 - precision_1: 0.7034 - recall_1: 0.6990 - val_loss: 0.6156 - val_accuracy: 0.6538 - val_precision_1: 0.6547 - val_recall_1: 0.6506

# %%
model.evaluate(x_test, y_test)
# Out:
# 782/782 [==============================] - 26s 33ms/step - loss: 0.6156 - accuracy: 0.6538 - precision_1: 0.6547 - recall_1: 0.6506
# [0.615589439868927, 0.6537600159645081, 0.6547254920005798, 0.6506400108337402]
